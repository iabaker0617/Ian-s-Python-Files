# %%
# Load necessary packages
import requests
import zipfile
import io
import paramiko
import os
import dtale
import pandas as pd
from pandasgui import show
import paramiko
import io
import os
import dtale
import time

# %%
file_path = r"C:\Users\iabaker\OneDrive - Boston University\Data Projects\Operations\2026 admissions cycle enrollment updates\Budget and Finance supplemental analysis\Enrollment projections based on admits_data table.xlsx"
ProjectedStudents = pd.read_excel(file_path)
dtale.show(ProjectedStudents)

# %%
degree_counts = ProjectedStudents['Graduate Application Degree'].value_counts()
print(degree_counts)
