# %%
import smtplib
from email.message import EmailMessage
import bokeh
import os
from pandasgui import show
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

# --- 1. Import Ian's file ---
IanDF = pd.read_excel(
    r"C:\Users\iabaker\Downloads\All Graduate Applications, Filterable by Year (43).xlsx"
)

# --- 2. Import Kelly's file ---
KellyDF = pd.read_excel(
    r"C:\Users\iabaker\Downloads\A2. 2) Graduate Admissions Report Builder (7).xlsx"
)
print(KellyDF.columns.tolist())
# Out:
# ['Person Id', 'LastName', 'MiddleName', 'FirstName', 'Applied To Year Semester', 'Unnamed: 5', 'Unnamed: 6', 'Graduate Application College', 'Graduate Application Major', 'Graduate Application Degree Level', 'Graduate Application Indicator', 'Graduate Current Row Indicator', 'Graduate Decision Status', 'Admissions Snapshot Date', '18 November, 2025 - Fall, 2025']

# %%
import pandas as pd

# --- 1. Import Ian's file ---
IanDF = pd.read_excel(
    r"C:\Users\iabaker\Downloads\All Graduate Applications, Filterable by Year (43).xlsx"
)

# --- 2. Import Kelly's file ---
KellyDF = pd.read_excel(
    r"C:\Users\iabaker\Downloads\A2. 2) Graduate Admissions Report Builder (6).xlsx"
)
IanDF.columns = IanDF.columns.str.strip()
KellyDF.columns = KellyDF.columns.str.strip()
# --- 3. Full outer join on Person Id ---
MergedDF = pd.merge(
    IanDF,
    KellyDF,
    on=["Person Id", "Graduate Application Major"],  # <-- pass a list
    how="outer"
)

# (Optional) View the result
print(MergedDF.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31348\1581933345.py in ?()
#      11 )
#      12 IanDF.columns = IanDF.columns.str.strip()
#      13 KellyDF.columns = KellyDF.columns.str.strip()
#      14 # --- 3. Full outer join on Person Id ---
# ---> 15 MergedDF = pd.merge(
#      16     IanDF,
#      17     KellyDF,
#      18     on=["Person Id", "Graduate Application Major"],  # <-- pass a list
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ...
